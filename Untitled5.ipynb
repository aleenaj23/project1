# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenaj23/project1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/movies[1].csv")
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
print(df.shape)
# Out:
# (9742, 3)

# %%
df1=pd.read_csv("/content/ratings[1].csv")

# %%
print(df1.shape)
# Out:
# (100836, 4)

# %%
df1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
unique=df1['userId'].nunique()
unique
# Out:
# 610

# %%
df2=pd.read_csv("/content/tags[1].csv")
df2
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df3=pd.read_csv("/content/links[1].csv")
df3
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
max=df1.loc[df1['rating'].idxmax()]['movieId']
max
# Out:
# 47.0

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df['movieId'],df['title']
# Out:
# (0            1
#  1            2
#  2            3
#  3            4
#  4            5
#           ...
#  9737    193581
#  9738    193583
#  9739    193585
#  9740    193587
#  9741    193609
#  Name: movieId, Length: 9742, dtype: int64,
#  0                                Toy Story (1995)
#  1                                  Jumanji (1995)
#  2                         Grumpier Old Men (1995)
#  3                        Waiting to Exhale (1995)
#  4              Father of the Bride Part II (1995)
#                            ...
#  9737    Black Butler: Book of the Atlantic (2017)
#  9738                 No Game No Life: Zero (2017)
#  9739                                 Flint (2017)
#  9740          Bungo Stray Dogs: Dead Apple (2018)
#  9741          Andrew Dice Clay: Dice Rules (1991)
#  Name: title, Length: 9742, dtype: object)

# %%
maxmid=count.idxmax()
maxmid
# Out:
# 356

# %%
count=df1.groupby('movieId').size()
count
# Out:
# movieId
# 1         215
# 2         110
# 3          52
# 4           7
# 5          49
#          ...
# 193581      1
# 193583      1
# 193585      1
# 193587      1
# 193609      1
# Length: 9724, dtype: int64

# %%
title=df.loc[df['movieId']==maxmid,'title'].values[0]
title
# Out:
# 'Forrest Gump (1994)'

# %%
mtitle="Matrix, The (1999)"

# %%
id=df.loc[df['title']==mtitle,'movieId'].values[0]

# %%
mtags=df2.loc[df2['movieId']==id,'tag']
mtags
# Out:
# 815           martial arts
# 816                 sci-fi
# 1646    alternate universe
# 2794            philosophy
# 2795      post apocalyptic
# Name: tag, dtype: object

# %%
mdata=pd.merge(df1,df,on='movieId')

# %%
te=mdata[mdata['title']=='Terminator 2: Judgment Day (1991)']

# %%
avg=te['rating'].mean()
avg
# Out:
# 3.970982142857143

# %%
fight_club_data = mdata[mdata['title'] == 'Fight Club']

# %%
import matplotlib.pyplot as plt

plt.hist(fight_club_data['rating'], bins=5, edgecolor='black')  # Adjust the number of bins as needed
plt.title('User Ratings Distribution for Fight Club')
plt.xlabel('Rating')
plt.ylabel('Number of Users')
plt.show()

# %%
# Calculate the number of ratings for each movie
ratings_count = mdata['title'].value_counts().reset_index()
ratings_count.columns = ['title', 'ratings_count']

# Filter movies with more than 50 user ratings
popular_movies = ratings_count[ratings_count['ratings_count'] > 50]

# Calculate average ratings for the popular movies
average_ratings = mdata.groupby('title')['rating'].mean().reset_index()

# Merge average ratings with the popular movies
popular_movies_with_ratings = pd.merge(popular_movies, average_ratings, on='title')

# Sort and identify the most popular movie
most_popular_movie = popular_movies_with_ratings.sort_values(by='rating', ascending=False).iloc[0]
print(f"The most popular movie with more than 50 user ratings is '{most_popular_movie['title']}' with an average rating of {most_popular_movie['rating']:.2f}")
# Out:
# The most popular movie with more than 50 user ratings is 'Shawshank Redemption, The (1994)' with an average rating of 4.43

# %%
# Calculate the number of ratings for each movie
ratings_count = mdata['title'].value_counts().reset_index()
ratings_count.columns = ['title', 'ratings_count']

# Filter movies with more than 50 user ratings
popular_movies = ratings_count[ratings_count['ratings_count'] > 50]

# %%
# Step 2: Join with Links to get IMDb IDs
movies_with_imdb = pd.merge(popular_movies,df3, on='movieId', how='inner')

# Step 3-5: Web scrape IMDb reviews and find the movie with the highest IMDb rating
# (Note: You need to implement web scraping separately)

# Example using BeautifulSoup for web scraping
from bs4 import BeautifulSoup
import requests

def scrape_imdb_reviews(imdb_id):
    # Implement web scraping logic here
    # Example: Use requests to get IMDb page and BeautifulSoup to parse it
    url = f'https://www.imdb.com/title/{imdb_id}/reviews/'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    # Extract review data

# Apply the scraping function to each movie with IMDb ID
movies_with_imdb['imdb_reviews'] = movies_with_imdb['imdbId'].apply(scrape_imdb_reviews)

# Extract IMDb ratings and find the movie with the highest rating
# (Assuming the IMDb rating is stored in a 'rating' column after scraping)
movies_with_imdb['imdb_rating'] = movies_with_imdb['imdb_reviews'].apply(lambda reviews: extract_imdb_rating(reviews))
highest_rated_movie = movies_with_imdb.loc[movies_with_imdb['imdb_rating'].idxmax()]

# Display the movie ID with the highest IMDb rating
print("Movie with the highest IMDb rating:", highest_rated_movie['movieId'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-69a9c48f4b1b> in <cell line: 20>()
#      18
#      19 # Apply the scraping function to each movie with IMDb ID
# ---> 20 movies_with_imdb['imdb_reviews'] = movies_with_imdb['imdbId'].apply(scrape_imdb_reviews)
#      21
#      22 # Extract IMDb ratings and find the movie with the highest rating
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# ...
